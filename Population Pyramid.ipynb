# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
dff = pd.read_csv("population/italy-2020.csv")
dff
# Out:
#       Age        M        F
# 0     0-4  1197289  1127405
# 1     5-9  1374731  1295570
# 2   10-14  1470174  1387183
# 3   15-19  1484455  1391636
# 4   20-24  1526577  1415929
# 5   25-29  1625230  1535700
# 6   30-34  1702976  1662536
# 7   35-39  1824273  1808649
# 8   40-44  2092329  2096655
# 9   45-49  2401070  2431950
# 10  50-54  2420466  2487780
# 11  55-59  2274884  2384062
# 12  60-64  1903045  2050522
# 13  65-69  1679600  1851695
# 14  70-74  1586760  1805038
# 15  75-79  1182323  1454787
# 16  80-84   958360  1344033
# 17  85-89   504059   893202
# 18  90-94   186608   453131
# 19  95-99    39461   133178
# 20   100+     3055    13462

# %%
males = dff.loc[:, 'Age':'M']
females = ['Age', 'F']
females = pd.DataFrame(dff, columns=females)

males.plot(kind = 'bar', xlabel = "Age bracket", ylabel = "Millions of people", color='blue')
females.plot(kind = 'bar', xlabel = "Age bracket", ylabel = "Millions of people", color= 'pink')
# Out:
# <AxesSubplot:xlabel='Age bracket', ylabel='Millions of people'>

# %%
dependancies = []
years = []
for i in range(2000, 2021):
    years.append(i)
    location = "population/italy-" + str(i) +".csv"
    dff = pd.read_csv(location)
    males = dff.loc[:, 'Age':'M']
    females = ['Age', 'F']
    females = pd.DataFrame(dff, columns=females)
    
    laborMales = males.iloc[0:3]
    laborMales = laborMales.append(males.iloc[13:20])
    inactiveMales = males.iloc[3:13]
    
    laborFemales = females.iloc[0:3]
    laborFemales = laborFemales.append(females.iloc[13:20])
    inactiveFemales = females.iloc[3:13]
    
    dependancy =    ((laborMales['M'].sum() + laborFemales['F'].sum()) / 
                    (inactiveMales['M'].sum()  + inactiveFemales['F'].sum()))
                    * 100
    dependancies.append(dependancy)
    
plt.plot(years, dependancies, marker = 'o')
plt.title("Italy's dependancy ratio from 2000 to 2020")
plt.xticks(np.arange(min(years), max(years)+5, 5.0))
plt.xlabel('Years')
plt.ylabel('Dependancy Ratio')
# Out:
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborMales = laborMales.append(males.iloc[13:20])
# <ipython-input-178-943cbff4e3af>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   laborFemales = laborFemales.append(females.iloc[13:20])
# Text(0, 0.5, 'Dependancy Ratio')

# %%
males = dff.loc[:, 'Age':'M']

females = ['Age', 'F']
females = pd.DataFrame(dff, columns=females)
females['F'] = females['F'].apply(lambda x: x * -1)   # Utilizziamo un 
                                                      # lambda per invertire 
                                                      # i valori di females

females = females['F'].values.tolist()
males = males['M'].values.tolist()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.DataFrame({'Age': ['0-4','5-9','10-14','15-19','20-24','25-29','30-34','35-39','40-44',
                           '45-49','50-54','55-59','60-64','65-69','70-74','75-79','80-84','85-89',
                           '90-94','95-99','100+'], 
                    'Males': males, 
                    'Females': females})
AgeClass = ['100+','95-99','90-94','85-89','80-84','75-79','70-74','65-69','60-64','55-59',
            '50-54','45-49','40-44','35-39','30-34','25-29','20-24','15-19','10-14','5-9','0-4']

bar_plot = sns.barplot(x='Males', y='Age', data=df, order=AgeClass, lw = 0)
bar_plot = sns.barplot(x='Females', y='Age', data=df, order=AgeClass, lw = 0)

bar_plot.set(xlabel="Population (hundreds of millions)", ylabel="Age-Group", title = "Population Pyramid")

fig = bar_plot.get_figure()
bar_plot.figure.savefig("output.png")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns



images = []
for i in range(2000, 2021):
    location = "population/italy-" + str(i) +".csv"
    dff = pd.read_csv(location)
    males = dff.loc[:, 'Age':'M']

    females = ['Age', 'F']
    females = pd.DataFrame(dff, columns=females)
    females['F'] = females['F'].apply(lambda x: x * -1)   # Utilizziamo un 
                                                      # lambda per invertire 
                                                      # i valori di females

    females = females['F'].values.tolist()
    males = males['M'].values.tolist()
    df = pd.DataFrame({'Age': ['0-4','5-9','10-14','15-19','20-24','25-29','30-34','35-39','40-44',
                           '45-49','50-54','55-59','60-64','65-69','70-74','75-79','80-84','85-89',
                           '90-94','95-99','100+'], 
                    'Males': males, 
                    'Females': females})
    AgeClass = ['100+','95-99','90-94','85-89','80-84','75-79','70-74','65-69','60-64','55-59',
            '50-54','45-49','40-44','35-39','30-34','25-29','20-24','15-19','10-14','5-9','0-4']

    bar_plot = sns.barplot(x='Males', y='Age', data=df, order=AgeClass, lw = 0)
    bar_plot = sns.barplot(x='Females', y='Age', data=df, order=AgeClass, lw = 0)

    bar_plot.set(xlabel="Population (millions)", ylabel="Age-Group", title = "Population Pyramid: " + str(i))

    fig = bar_plot.get_figure()
    output = "output" + str(i)
    bar_plot.figure.savefig("italy/" + output)
import os
import imageio

png_dir = 'italy/'
images = []
for file_name in sorted(os.listdir(png_dir)):
    if file_name.endswith('.png'):
        file_path = os.path.join(png_dir, file_name)
        images.append(imageio.imread(file_path))
imageio.mimsave('italyMovie.gif', images)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns



images = []
for i in range(2000, 2021):
    location = "population/China-" + str(i) +".csv"
    dff = pd.read_csv(location)
    males = dff.loc[:, 'Age':'M']

    females = ['Age', 'F']
    females = pd.DataFrame(dff, columns=females)
    females['F'] = females['F'].apply(lambda x: x * -1)   # Utilizziamo un 
                                                      # lambda per invertire 
                                                      # i valori di females

    females = females['F'].values.tolist()
    males = males['M'].values.tolist()
    df = pd.DataFrame({'Age': ['0-4','5-9','10-14','15-19','20-24','25-29','30-34','35-39','40-44',
                           '45-49','50-54','55-59','60-64','65-69','70-74','75-79','80-84','85-89',
                           '90-94','95-99','100+'], 
                    'Males': males, 
                    'Females': females})
    AgeClass = ['100+','95-99','90-94','85-89','80-84','75-79','70-74','65-69','60-64','55-59',
            '50-54','45-49','40-44','35-39','30-34','25-29','20-24','15-19','10-14','5-9','0-4']

    bar_plot = sns.barplot(x='Males', y='Age', data=df, order=AgeClass, lw = 0)
    bar_plot = sns.barplot(x='Females', y='Age', data=df, order=AgeClass, lw = 0)

    bar_plot.set(xlabel="Population (tens of millions)", ylabel="Age-Group", title = "Population Pyramid: " + str(i))
    #fig = bar_plot.get_figure()
    
    
    output = "output" + str(i)
    bar_plot.figure.savefig("china/" + output)
    
    
import os
import imageio

png_dir = 'china/'
images = []
for file_name in sorted(os.listdir(png_dir)):
    if file_name.endswith('.png'):
        file_path = os.path.join(png_dir, file_name)
        images.append(imageio.imread(file_path))
imageio.mimsave('chinaMovie.gif', images)
print("Done")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns



images = []
for i in range(2000, 2021):
    location = "population/WORLD-" + str(i) +".csv"
    dff = pd.read_csv(location)
    males = dff.loc[:, 'Age':'M']

    females = ['Age', 'F']
    females = pd.DataFrame(dff, columns=females)
    females['F'] = females['F'].apply(lambda x: x * -1)   # Utilizziamo un 
                                                      # lambda per invertire 
                                                      # i valori di females

    females = females['F'].values.tolist()
    males = males['M'].values.tolist()
    df = pd.DataFrame({'Age': ['0-4','5-9','10-14','15-19','20-24','25-29','30-34','35-39','40-44',
                           '45-49','50-54','55-59','60-64','65-69','70-74','75-79','80-84','85-89',
                           '90-94','95-99','100+'], 
                    'Males': males, 
                    'Females': females})
    AgeClass = ['100+','95-99','90-94','85-89','80-84','75-79','70-74','65-69','60-64','55-59',
            '50-54','45-49','40-44','35-39','30-34','25-29','20-24','15-19','10-14','5-9','0-4']

    bar_plot = sns.barplot(x='Males', y='Age', data=df, order=AgeClass, lw = 0)
    bar_plot = sns.barplot(x='Females', y='Age', data=df, order=AgeClass, lw = 0)

    bar_plot.set(xlabel="Population (billions)", ylabel="Age-Group", title = "Population Pyramid: " + str(i))
    #fig = bar_plot.get_figure()
    
    
    output = "output" + str(i)
    bar_plot.figure.savefig("world/" + output)
    
    
import os
import imageio

png_dir = 'world/'
images = []
for file_name in sorted(os.listdir(png_dir)):
    if file_name.endswith('.png'):
        file_path = os.path.join(png_dir, file_name)
        images.append(imageio.imread(file_path))
imageio.mimsave('worldMovie.gif', images)
print("Done")
# Out:
# Done
